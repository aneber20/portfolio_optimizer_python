# %%
import yfinance as yf
from analytics import fetch_sp500_returns

data  = yf.download("AAPL", period="1y")
data.head()
# Out:
# /tmp/ipykernel_137284/3803157774.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data  = yf.download("AAPL", period="1y")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2024-11-01  221.877396  224.306095  219.249626  219.946380  65276700
# 2024-11-04  220.981537  221.757922  218.692204  219.966273  44944500
# 2024-11-05  222.414856  222.912540  220.115560  220.772506  28111300
# 2024-11-06  221.688263  225.022750  220.165352  221.578772  54561100
# 2024-11-07  226.426193  226.824349  223.529685  223.589405  42137700

# %%
fetch_sp500_returns(['10y', '5y', '1y', '6mo', '3mo', '1mo', '1wk'])
# Out:
# {'10y': np.float64(2.8647382267740134),
#  '5y': np.float64(1.2237946184134865),
#  '1y': np.float64(0.20963829971867323),
#  '6mo': np.float64(0.2287420265275593),
#  '3mo': np.float64(0.10041691583822814),
#  '1mo': np.float64(0.020290561782242034),
#  '1wk': np.float64(-0.004698447575644841)}

# %%
data  = yf.download("MSFT", period="1y")
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['MSFT']: JSONDecodeError('Expecting value: line 1 column 1 (char 0)')
# Empty DataFrame
# Columns: [(Adj Close, MSFT), (Close, MSFT), (High, MSFT), (Low, MSFT), (Open, MSFT), (Volume, MSFT)]
# Index: []

# %%
dat = yf.Ticker("MSFT")
dat.info
dat.calendar
dat.analyst_price_targets
dat.quarterly_income_stmt
dat.history(period='1mo')
dat.option_chain(dat.options[0]).calls
# Out:
# 429 Client Error: Too Many Requests for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/MSFT?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=MSFT&crumb=Edge%3A+Too+Many+Requests
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 dat = yf.Ticker("MSFT")
# ----> 2 dat.info
#       3 dat.calendar
#       4 dat.analyst_price_targets
#
# File ~/vscode-projects/portfolio_optimizer_python/.venv/lib/python3.10/site-packages/yfinance/ticker.py:159, in Ticker.info(self)
#     157 @property
#     158 def info(self) -> dict:
# --> 159     return self.get_info()
#
# File ~/vscode-projects/portfolio_optimizer_python/.venv/lib/python3.10/site-packages/yfinance/base.py:230, in TickerBase.get_info(self, proxy)
#     228 def get_info(self, proxy=None) -> dict:
#     229     self._quote.proxy = proxy or self.proxy
# --> 230     data = self._quote.info
#     231     return data
#
# File ~/vscode-projects/portfolio_optimizer_python/.venv/lib/python3.10/site-packages/yfinance/scrapers/quote.py:509, in Quote.info(self)
#     507 if self._info is None:
#     508     self._fetch_info(self.proxy)
# --> 509     self._fetch_complementary(self.proxy)
#     511 return self._info
#
# File ~/vscode-projects/portfolio_optimizer_python/.venv/lib/python3.10/site-packages/yfinance/scrapers/quote.py:684, in Quote._fetch_complementary(self, proxy)
#     681 url += f"&period1={start}&period2={end}"
#     683 json_str = self._data.cache_get(url=url, proxy=proxy).text
# --> 684 json_data = json.loads(json_str)
#     685 json_result = json_data.get("timeseries") or json_data.get("finance")
#     686 if json_result["error"] is not None:
#
# File /usr/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /usr/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /usr/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
